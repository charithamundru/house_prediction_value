# %% [markdown]
# # House Price Prediction
# This notebook uses the production modules in `src/` so exploration and deployment share one leakage-safe implementation.

# %% [markdown]
# ## Run the pipeline
# Place `Housing.csv` in `data/`, then run the next cell. EDA reports, plots, metrics, and serialized artifacts are generated automatically.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))
from src.train import train_project
comparison = train_project()
comparison

# %% [markdown]
# ## Review results
# Open `reports/executive_eda_report.md` for the executive summary and `outputs/metrics.json` for deployment metrics. The fitted pipeline includes preprocessing and can be loaded directly with joblib.

# %%
import json
from pathlib import Path
json.loads(Path('outputs/metrics.json').read_text())
